# %%
import os
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from matplotlib import pyplot as plt
import numpy as np

# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# Prepare dataset with shuffle enabled
data = tf.keras.utils.image_dataset_from_directory(
    './palm_diseases_data/', 
    image_size=(256, 256),
    color_mode='rgb', 
    batch_size=32, 
    shuffle=True  # Shuffle data
)


# Split sizes
train_size = 0.7  # 70% training data
val_size = 0.15   # 15% validation data
test_size = 0.15  # 15% test data

# Calculate the number of batches in the dataset
total_batches = tf.data.experimental.cardinality(data).numpy()

train_batches = int(total_batches * train_size)
val_batches = int(total_batches * val_size)
test_batches = int(total_batches * test_size)

# Split the dataset using the calculated sizes
train = data.take(train_batches)
val_test = data.skip(train_batches)
val = val_test.take(val_batches)
test = val_test.skip(val_batches)

# Optionally, prefetch the data for better performance
train = train.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
val = val.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
test = test.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# Apply data augmentation only to the training set
train = train.map(lambda x, y: (tf.image.random_flip_left_right(x), y))

# Load the pre-trained MobileNetV2 model
base_model = MobileNetV2(input_shape=(256, 256, 3), include_top=False, weights='imagenet')

# Unfreeze the top layers of the base model
for layer in base_model.layers[-30:]:  # Unfreeze the last 30 layers
    layer.trainable = True

# Build the model with regularization, batch normalization, and additional layers
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # More efficient than Flatten()
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(10, activation='softmax')  # Output layer for 9 classes
])

# Compile the model with learning rate scheduler
initial_learning_rate = 1e-3
lr_schedule = LearningRateScheduler(lambda epoch: initial_learning_rate * 10 ** (-epoch / 20))

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Early Stopping to avoid overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# TensorBoard callback for visualization
logdir = 'logs'
tensorboard_callback = TensorBoard(log_dir=logdir)

# Train the model
hist = model.fit(
    train, 
    epochs=50, 
    validation_data=val, 
    callbacks=[early_stopping, tensorboard_callback, lr_schedule, reduce_lr]
)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test)
print(f'Test accuracy: {test_acc:.4f}')

# Ensure the directory exists
# model_dir = 'models'
# if not os.path.exists(model_dir):
#     os.makedirs(model_dir)

# # Save the model to the 'models' directory
# model_path = os.path.join(model_dir, 'palm_tree_health_model.h5')
# model.save(model_path)
# print(f'Model saved to {model_path}')
# Out:
# Found 3944 files belonging to 10 classes.
# /var/folders/n9/t793s4995b354q_1jpbvkkl40000gn/T/ipykernel_3191/362652755.py:53: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(256, 256, 3), include_top=False, weights='imagenet')
# Epoch 1/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 358s 4s/step - accuracy: 0.2628 - loss: 3.8568 - val_accuracy: 0.1163 - val_loss: 13.4341 - learning_rate: 0.0010
# Epoch 2/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 348s 4s/step - accuracy: 0.5491 - loss: 2.5553 - val_accuracy: 0.1823 - val_loss: 9.7357 - learning_rate: 8.9125e-04
# Epoch 3/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 391s 5s/step - accuracy: 0.6781 - loss: 2.0769 - val_accuracy: 0.1476 - val_loss: 10.2624 - learning_rate: 7.9433e-04
# Epoch 4/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 334s 4s/step - accuracy: 0.7405 - loss: 1.8373 - val_accuracy: 0.3177 - val_loss: 8.4146 - learning_rate: 7.0795e-04
# Epoch 5/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 357s 4s/step - accuracy: 0.8002 - loss: 1.5994 - val_accuracy: 0.3264 - val_loss: 5.4194 - learning_rate: 6.3096e-04
# Epoch 6/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 366s 4s/step - accuracy: 0.8133 - loss: 1.5241 - val_accuracy: 0.3628 - val_loss: 4.5727 - learning_rate: 5.6234e-04
# Epoch 7/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 360s 4s/step - accuracy: 0.8634 - loss: 1.3693 - val_accuracy: 0.3316 - val_loss: 5.3074 - learning_rate: 5.0119e-04
# Epoch 8/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 335s 4s/step - accuracy: 0.8708 - loss: 1.2737 - val_accuracy: 0.3681 - val_loss: 5.5179 - learning_rate: 4.4668e-04
# Epoch 9/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 355s 4s/step - accuracy: 0.8889 - loss: 1.2470 - val_accuracy: 0.4427 - val_loss: 4.0641 - learning_rate: 3.9811e-04
# Epoch 10/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2094s 25s/step - accuracy: 0.8995 - loss: 1.1484 - val_accuracy: 0.6302 - val_loss: 2.4155 - learning_rate: 3.5481e-04
# Epoch 11/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 293s 3s/step - accuracy: 0.9181 - loss: 1.0963 - val_accuracy: 0.6476 - val_loss: 2.4661 - learning_rate: 3.1623e-04
# Epoch 12/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.9396 - loss: 1.0017 - val_accuracy: 0.6597 - val_loss: 2.2265 - learning_rate: 2.8184e-04
# Epoch 13/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 195s 2s/step - accuracy: 0.9488 - loss: 0.9698 - val_accuracy: 0.6719 - val_loss: 2.2470 - learning_rate: 2.5119e-04
# Epoch 14/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.9517 - loss: 0.9312 - val_accuracy: 0.6927 - val_loss: 2.0955 - learning_rate: 2.2387e-04
# Epoch 15/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 183s 2s/step - accuracy: 0.9635 - loss: 0.8862 - val_accuracy: 0.7135 - val_loss: 2.0411 - learning_rate: 1.9953e-04
# Epoch 16/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - accuracy: 0.9678 - loss: 0.8366 - val_accuracy: 0.8264 - val_loss: 1.3939 - learning_rate: 1.7783e-04
# Epoch 17/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - accuracy: 0.9651 - loss: 0.8329 - val_accuracy: 0.8490 - val_loss: 1.3097 - learning_rate: 1.5849e-04
# Epoch 18/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.9786 - loss: 0.7844 - val_accuracy: 0.8559 - val_loss: 1.2999 - learning_rate: 1.4125e-04
# Epoch 19/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.9783 - loss: 0.7738 - val_accuracy: 0.8646 - val_loss: 1.3867 - learning_rate: 1.2589e-04
# Epoch 20/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - accuracy: 0.9829 - loss: 0.7533 - val_accuracy: 0.9028 - val_loss: 1.1384 - learning_rate: 1.1220e-04
# Epoch 21/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.9902 - loss: 0.7244 - val_accuracy: 0.8854 - val_loss: 1.1578 - learning_rate: 1.0000e-04
# Epoch 22/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - accuracy: 0.9821 - loss: 0.7368 - val_accuracy: 0.8785 - val_loss: 1.2234 - learning_rate: 8.9125e-05
# Epoch 23/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.9882 - loss: 0.7180 - val_accuracy: 0.9045 - val_loss: 1.0506 - learning_rate: 7.9433e-05
# Epoch 24/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.9917 - loss: 0.6949 - val_accuracy: 0.8993 - val_loss: 1.0776 - learning_rate: 7.0795e-05
# Epoch 25/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.9942 - loss: 0.6829 - val_accuracy: 0.9167 - val_loss: 0.9906 - learning_rate: 6.3096e-05
# Epoch 26/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.9913 - loss: 0.6872 - val_accuracy: 0.9236 - val_loss: 0.9906 - learning_rate: 5.6234e-05
# Epoch 27/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.9904 - loss: 0.6697 - val_accuracy: 0.9062 - val_loss: 1.0406 - learning_rate: 5.0119e-05
# Epoch 28/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.9932 - loss: 0.6580 - val_accuracy: 0.9167 - val_loss: 0.9733 - learning_rate: 4.4668e-05
# Epoch 29/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 243s 3s/step - accuracy: 0.9942 - loss: 0.6580 - val_accuracy: 0.9184 - val_loss: 0.9640 - learning_rate: 3.9811e-05
# Epoch 30/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 221s 3s/step - accuracy: 0.9949 - loss: 0.6465 - val_accuracy: 0.9201 - val_loss: 0.9837 - learning_rate: 3.5481e-05
# Epoch 31/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.9951 - loss: 0.6397 - val_accuracy: 0.9410 - val_loss: 0.8929 - learning_rate: 3.1623e-05
# Epoch 32/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 212s 2s/step - accuracy: 0.9936 - loss: 0.6435 - val_accuracy: 0.9323 - val_loss: 0.9568 - learning_rate: 2.8184e-05
# Epoch 33/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 212s 2s/step - accuracy: 0.9934 - loss: 0.6442 - val_accuracy: 0.9410 - val_loss: 0.8566 - learning_rate: 2.5119e-05
# Epoch 34/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 216s 3s/step - accuracy: 0.9954 - loss: 0.6286 - val_accuracy: 0.9358 - val_loss: 0.9269 - learning_rate: 2.2387e-05
# Epoch 35/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 237s 3s/step - accuracy: 0.9963 - loss: 0.6262 - val_accuracy: 0.9253 - val_loss: 0.9644 - learning_rate: 1.9953e-05
# Epoch 36/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.9962 - loss: 0.6234 - val_accuracy: 0.9392 - val_loss: 0.9059 - learning_rate: 1.7783e-05
# Epoch 37/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - accuracy: 0.9974 - loss: 0.6176 - val_accuracy: 0.9392 - val_loss: 0.9159 - learning_rate: 1.5849e-05
# Epoch 38/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 222s 3s/step - accuracy: 0.9936 - loss: 0.6227 - val_accuracy: 0.9427 - val_loss: 0.8499 - learning_rate: 1.4125e-05
# Epoch 39/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.9958 - loss: 0.6148 - val_accuracy: 0.9392 - val_loss: 0.9033 - learning_rate: 1.2589e-05
# Epoch 40/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.9942 - loss: 0.6163 - val_accuracy: 0.9427 - val_loss: 0.8745 - learning_rate: 1.1220e-05
# Epoch 41/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.9977 - loss: 0.6066 - val_accuracy: 0.9427 - val_loss: 0.8918 - learning_rate: 1.0000e-05
# Epoch 42/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.9950 - loss: 0.6100 - val_accuracy: 0.9358 - val_loss: 0.8641 - learning_rate: 8.9125e-06
# Epoch 43/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.9978 - loss: 0.6055 - val_accuracy: 0.9340 - val_loss: 0.9078 - learning_rate: 7.9433e-06
# Epoch 44/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 182s 2s/step - accuracy: 0.9979 - loss: 0.6024 - val_accuracy: 0.9375 - val_loss: 0.9227 - learning_rate: 7.0795e-06
# Epoch 45/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.9964 - loss: 0.6050 - val_accuracy: 0.9427 - val_loss: 0.8869 - learning_rate: 6.3096e-06
# Epoch 46/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 182s 2s/step - accuracy: 0.9950 - loss: 0.6053 - val_accuracy: 0.9462 - val_loss: 0.8446 - learning_rate: 5.6234e-06
# Epoch 47/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.9973 - loss: 0.6027 - val_accuracy: 0.9375 - val_loss: 0.8873 - learning_rate: 5.0119e-06
# Epoch 48/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.9957 - loss: 0.6000 - val_accuracy: 0.9392 - val_loss: 0.8940 - learning_rate: 4.4668e-06
# Epoch 49/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 193s 2s/step - accuracy: 0.9950 - loss: 0.6048 - val_accuracy: 0.9410 - val_loss: 0.8570 - learning_rate: 3.9811e-06
# Epoch 50/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9936 - loss: 0.6036 - val_accuracy: 0.9358 - val_loss: 0.8654 - learning_rate: 3.5481e-06
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 12s 312ms/step - accuracy: 0.9184 - loss: 0.9408
# Test accuracy: 0.9140

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get true labels and predicted labels
y_true = []
y_pred = []

for images, labels in test:  # Iterate over the test dataset batches
    predictions = model.predict(images)  # Get the predictions
    predicted_labels = np.argmax(predictions, axis=1)  # Get the class with the highest probability
    
    y_true.extend(labels.numpy())  # Append true labels
    y_pred.extend(predicted_labels)  # Append predicted labels

# Convert the lists to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Greens)

plt.title("Confusion Matrix")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 847ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# 2024-09-30 17:52:17.811147: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
from sklearn.metrics import classification_report

# Assuming y_true and y_pred are already collected from the test set
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       148
#            1       0.98      0.97      0.98        64
#            2       0.90      0.97      0.93        93
#            3       0.88      0.83      0.85        35
#            4       0.62      0.65      0.64        23
#            5       0.84      0.84      0.84        51
#            6       0.86      0.86      0.86        69
#            7       0.95      0.82      0.88        22
#            8       0.96      1.00      0.98        65
#            9       1.00      0.91      0.95        46
#
#     accuracy                           0.91       616
#    macro avg       0.89      0.88      0.89       616
# weighted avg       0.91      0.91      0.91       616
